# %% [markdown]
# # Calculadora de Juros Compostos
# ## Simulador interativo de investimentos
#
# Versao refatorada com fases dinamicas, validacao robusta e feedback inteligente.

# %%
from calculadora import criar_interface

interface = criar_interface()
interface

# %%
# Exportar dados da ultima simulacao (execute apos simular)
# import pandas as pd
# df = pd.read_csv(...) ou use a variavel do escopo
# df.to_csv('simulacao_mes_a_mes.csv', index=False, decimal=',', sep=';')
# df.to_excel('simulacao_mes_a_mes.xlsx', index=False)

print("Descomente as linhas acima para exportar.")
